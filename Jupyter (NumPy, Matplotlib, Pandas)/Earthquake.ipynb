# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm, rcParams
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from matplotlib.ticker import FormatStrFormatter
import os
import seaborn as sns

# %%
earthquakes = pd.read_csv('all_month.csv')
earthquakes.head()
# Out:
#                        time   latitude   longitude      depth   mag magType  \
# 0  2021-11-25T02:22:39.990Z  33.665833 -116.775667  14.430000  0.98      ml
# 1  2021-11-25T02:18:47.640Z  38.564999 -119.455498   2.500000  2.11      md
# 2  2021-11-25T02:16:05.228Z  36.368938  -97.340614   2.847088  2.34      ml
# 3  2021-11-25T02:04:54.180Z  19.188499 -155.487167  30.600000  1.72      ml
# 4  2021-11-25T01:57:27.020Z  33.490500 -116.785167   3.350000  1.38      ml
#
#     nst        gap      dmin       rms  ...                   updated  \
# 0  38.0  45.000000  0.068370  0.230000  ...  2021-11-25T02:26:24.796Z
# 1   9.0  83.000000  0.054610  0.080000  ...  2021-11-25T02:26:11.519Z
# 2  45.0  55.237244  0.091238  0.567835  ...  2021-11-25T02:18:42.143Z
# 3  45.0  76.000000       NaN  0.130000  ...  2021-11-25T02:10:24.830Z
# 4  57.0  32.000000  0.025230  0.200000  ...  2021-11-25T02:08:35.040Z
#
#                          place        type horizontalError depthError  \
# ...

# %%
fig, ax = plt.subplots()
earthquakes.boxplot(column=['mag'], ax=ax)
ax.set_title('Magnitude')
ax.set_ylabel('In the world 0 ≥ 6')
# Out:
# Text(0, 0.5, 'In the world 0 ≥ 6')

# %%
colors = ["#F6752A","#008B8B", "#6F9C56", "#9660C9", "#B81B27"]

# %%
eq = pd.read_csv('all_month.csv')
plt.plot(eq.mag)
plt.title('Magnitude evensts from 26/10 to 25/11/21')
plt.ylabel('In the world ≥ 6')
plt.xlabel('Cases')
# Out:
# Text(0.5, 0, 'Cases')

# %%
bins = [0,1,2,3,4,5,6]
plt.hist(eq.mag, bins=bins)
plt.title('Magnitude evensts from 26/10 to 25/11/21')
plt.ylabel('Cases')
plt.xlabel('Manitude')
plt.show()

# %%
plt.hist(eq.place, bins=5)
plt.title('Magnitude evensts from 26/10 to 25/11/21')
plt.ylabel('Cases')
plt.xlabel('Magnitude')
plt.show()

# %% [markdown]
# eq2 = pd.read_csv('all.csv.xls')
# eq2.head()

# %%
earthquakes['mag_rounded']=round(earthquakes['mag'])
earthquakes
# Out:
#                           time   latitude   longitude       depth   mag  \
# 0     2021-11-25T02:22:39.990Z  33.665833 -116.775667   14.430000  0.98
# 1     2021-11-25T02:18:47.640Z  38.564999 -119.455498    2.500000  2.11
# 2     2021-11-25T02:16:05.228Z  36.368938  -97.340614    2.847088  2.34
# 3     2021-11-25T02:04:54.180Z  19.188499 -155.487167   30.600000  1.72
# 4     2021-11-25T01:57:27.020Z  33.490500 -116.785167    3.350000  1.38
# ...                        ...        ...         ...         ...   ...
# 9354  2021-10-26T03:00:34.922Z  62.869200 -151.236000  108.000000  1.40
# 9355  2021-10-26T02:56:37.950Z  39.431000 -110.326833   -1.220000  1.39
# 9356  2021-10-26T02:52:34.940Z  47.563167 -114.135167    5.210000 -0.13
# 9357  2021-10-26T02:46:44.410Z  53.858833 -166.763000    7.030000  0.00
# 9358  2021-10-26T02:39:32.600Z  38.423833 -122.626833    5.210000  1.97
#
#      magType   nst         gap      dmin       rms  ...  \
# ...

# %%
sns.set_theme(style="white")
sns.relplot(x="latitude", y="longitude",  size="mag", hue='mag_rounded', alpha=.5, 
            palette="rocket", height=7, data=earthquakes)
plt.title('Magnitude events from 26/10 to 25/11/21')
# Out:
# Text(0.5, 1.0, 'Magnitude events from 26/10 to 25/11/21')

# %%
ranges = [-1,0,1,2,3,4,5,6,7]
range_count = pd.DataFrame(earthquakes['mag'].groupby(pd.cut(earthquakes.mag, ranges)).count())
plt.plot(range_count)
# Out:
# C:\Users\mathe\anaconda3\lib\site-packages\matplotlib\axes\_base.py:507: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]

# %%
eq['time']=pd.to_datetime(eq['time'], format='%Y-%m-%dT%H:%M:%S.%fZ')
#note format needs to exactly match the format of the date in the column
eq=eq.set_index(['time'])
eq[['magError']].plot()
# Out:
# <AxesSubplot:xlabel='time'>
